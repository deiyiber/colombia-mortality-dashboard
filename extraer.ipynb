# %%
import process as datos
# --- Datos del mapa ---
df = datos.data_mapa()
lineal1=datos.grafico_lineal()
# --- Datos del gráfico de barras ---
df_ciudades = datos.grafico_barras()
# --- Datos del gráfico circular ---
circular = datos.grafico_circular()
# --- Datos del gráfico apilado ---
apiladas = datos.grafico_apiladas()
# --- Datos del histograma ---
histogra = datos.histograma()
# --- Datos de la tabla ---
tablita = datos.tabla()
# Out:
#  Total de muertes por sexo y departamento:
#                                         departamento  sexo  total_muertes
# 0                                           AMAZONAS     1           1375
# 1                                           AMAZONAS     2            715
# 2                                          ANTIOQUIA     1        2372250
# 3                                          ANTIOQUIA     2        1935125
# 4                                          ANTIOQUIA     3           1750
# 5                                             ARAUCA     1           5187
# 6                                             ARAUCA     2           2961
# 7  ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANT...     1            296
# 8  ARCHIPIELAGO DE SAN ANDRES, PROVIDENCIA Y SANT...     2            182
# 9                                          ATLANTICO     1         178917

# %%
df.to_csv("info/mapa.csv",sep='|',encoding='latin1',index=False)

# %%
lineal1.to_csv("info/lineal.csv",sep='|',encoding='latin1',index=False)
df_ciudades.to_csv("info/df_ciudades.csv",sep='|',encoding='latin1',index=False)
circular.to_csv("info/circular.csv",sep='|',encoding='latin1',index=False)
apiladas.to_csv("info/apiladas.csv",sep='|',encoding='latin1',index=False)
histogra.to_csv("info/histogra.csv",sep='|',encoding='latin1',index=False)
tablita.to_csv("info/tablita.csv",sep='|',encoding='latin1',index=False)
